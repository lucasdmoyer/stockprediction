# %%
import pandas as pd
import datetime
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
df = pd.read_csv('AAPL.csv')
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 245  2019-08-26  205.860001  207.190002  205.059998  206.490005  206.490005
# 246  2019-08-27  207.860001  208.550003  203.529999  204.160004  204.160004
# 247  2019-08-28  204.100006  205.720001  203.320007  205.529999  205.529999
# 248  2019-08-29  208.500000  209.320007  206.660004  209.009995  209.009995
# 249  2019-08-30  210.160004  210.449997  207.199997  208.740005  208.740005
#
#        Volume
# 245  26043600
# 246  25873300
# 247  15938800
# 248  20990500
# 249  21143400

# %%
# rolling mean
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()
plt.scatter(x=df['Date'], y=mavg, alpha=0.5)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %%
# return deviation - to determine risk and return
rets = close_px / close_px.shift(1) - 1
rets.plot(label='return')

# %% [markdown]
# # Ordinary Least Squares

# %%
# Create an float based date system
df['Date'] = pd.to_datetime(df['Date'])    
df['date_delta'] = (df['Date'] - df['Date'].min())  / np.timedelta64(1,'D')
df['date_delta'].head()
dates = df['date_delta'].to_numpy()
dates = dates.reshape(-1,1)
open_values = df['Open'].to_numpy()
open_values = open_values.reshape(-1,1)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X=open_values, y=df['Adj Close'])
df['linear_regression'] = reg.predict(dates)

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm
clf_svm = svm.SVR()
clf_svm.fit(X=open_values, y=df['Adj Close'])
df['support_vector_machine'] = reg.predict(dates)
# Out:
# C:\Users\moyer\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# # Bayesian Ridge Regression

# %%
from sklearn import linear_model
reg_bayes = linear_model.BayesianRidge()
reg_bayes.fit(X=dates, y=df['Adj Close'])
df['bayesian_ridge'] = reg_bayes.predict(dates)

# %% [markdown]
# # Visualizing the results

# %%
close_px = df['Adj Close']
linear_regression = df['linear_regression']
support_vector_machine= df['support_vector_machine']
bayesian_ridge = df['bayesian_ridge']

mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
linear_regression.plot(label='linear regression')
support_vector_machine.plot(label='support vector machine')
bayesian_ridge.plot(label='bayesian ridge regression')
plt.legend()
